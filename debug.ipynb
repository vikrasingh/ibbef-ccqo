# %%
import numpy as np
from scipy import linalg
import testalg

num_dim=1   # no. of examples of different dimensions
dim_egs=np.array([5, 20, 30])  # dimension of examples
num_data_pts=np.array([30, 50, 60])
num_k_values=1    
k_values=np.array([3, 4, 5]) 
s0_values=2*np.ones(num_dim,dtype=int) # no. of nonzero values in b0
num_instances=1           # no. of instances to run for each example
alg_flag=np.array([1, 1]) # =1 include in testing, =0 do not include  
num_alg=2
b0_type=1   # to generate the true coefficient vector b0

# initialize the arrays to save the final output
rss=np.zeros( (num_dim*num_k_values,num_alg) )
cpu_time=np.zeros( (num_dim*num_k_values,num_alg) )
num_iter=np.zeros( (num_dim*num_k_values,num_alg) )
stop_flag=-1*np.zeros( (num_dim*num_k_values,num_alg) )
for i in range(num_dim):

    p=dim_egs[i]
    n=num_data_pts[i]
    mu=np.zeros(p)
    sigma=np.eye(p)
    s0=s0_values[i]
    if b0_type==1: # example 1
        b0=np.zeros(p)
        i0=np.ceil(np.linspace(0,p,num=s0,endpoint=False)).astype(int) # get s0 evenly spaced indices, round the next integer if needed
        b0[i0]=1 
    elif b0_type==2: # example 2
        b0=np.zeros(p)
        b0[0:s0]=1 # make first s0 entries 1
    elif b0_type==3: # example 3
        b0=np.zeros(p)   
        i0 = np.random.randint(0,p,s0).astype(int) # pick s0 random indices to make nonzero
        j0 = np.random.randint(1,5,s0) # pick s0 random integers b/w 1 and 5
        b0[i0]=j0

    b0 = np.reshape(b0, (-1,1)) # make it a col array
    
    # run the algorithms and save the output
    for j in range(num_k_values): # for each k value, run the alg
        
        k = k_values[j]
        stop_flag_each_alg, cpu_time_each_alg, rss_each_alg=testalg.main(p,n,k,b0,mu,sigma,num_instances,num_alg,alg_flag)
        rss[j+i*num_k_values,:]=rss_each_alg
        cpu_time[j+i*num_k_values,:]=cpu_time_each_alg
        stop_flag[j+i*num_k_values,:]=stop_flag_each_alg

    # save the output in .pkl file
    print('rss:',rss)
    print('cpu:',cpu_time)
# Out:
# A,b,c: [[ 2.          0.47012747  0.4090279   0.34899272 -0.53074882]
#  [ 0.47012747  2.          0.83474769 -0.22215772  0.17466388]
#  [ 0.4090279   0.83474769  2.         -0.36060233  0.87273784]
#  [ 0.34899272 -0.22215772 -0.36060233  2.          0.58575358]
#  [-0.53074882  0.17466388  0.87273784  0.58575358  2.        ]] [[-0.63526821]
#  [-0.38474006]
#  [-0.24027198]
#  [-1.23857424]
#  [-0.75933276]] 2.9453397619274906
# p,k= 5 3
# x0,fx0: [[0.32350718]
#  [0.        ]
#  [0.        ]
#  [0.46651321]
#  [0.32888602]] 2.4288102621281937
# ipiv0: [2 3 0 1 4]
# ipiv1: []
# npiv0, npiv00: 5 5
# supp: [2 1 4]
# Ahat: [[ 2.          0.34899272 -0.53074882]
#  [ 0.34899272  2.          0.58575358]
#  [-0.53074882  0.58575358  2.        ]]
# bhat: [-0.63526821 -1.23857424 -0.75933276]
# c: 2.9453397619274906
# xout,fout: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xbest,fbest: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xlb : [[-0.07733803]
#  [ 0.47376649]
#  [ 0.29889061]
#  [ 0.17745594]
#  [ 0.33847943]]
# fxlb: 2.403649040818212
# Selected node Y: (2.403649040818212, 0, array([1, 1, 1, 1, 1]), 0, 5, 0, array([[-0.07733803],
#        [ 0.47376649],
#        [ 0.29889061],
#        [ 0.17745594],
#        [ 0.33847943]]))
# par_dir: [4 3 2 1 0]
# V0: [array([1, 1, 1, 1, 0]), 1, 4, 0]
# supp: [3 2 1]
# Ahat: [[ 2.          0.47012747 -0.22215772]
#  [ 0.47012747  2.          0.34899272]
#  [-0.22215772  0.34899272  2.        ]]
# bhat: [-0.38474006 -0.63526821 -1.23857424]
# c: 2.9453397619274906
# xout,fout: [[0.        ]
#  [0.61668886]
#  [0.15739993]
#  [0.22387211]
#  [0.        ]] 2.4703704224566696
# xtilde, fxtilde: [[0.        ]
#  [0.61668886]
#  [0.15739993]
#  [0.22387211]
#  [0.        ]] 2.4703704224566696
# F call for V0
# #1 flag < npiv0
# Back sub xhat: [[0.13415216]
#  [0.63890886]
#  [0.13757248]
#  [0.1750094 ]
#  [0.        ]]
# xlbV0,fxlbV0: [[0.13415216]
#  [0.63890886]
#  [0.13757248]
#  [0.1750094 ]
#  [0.        ]] 2.4561909598934384
# V0 got deleted using DC1
# V2: [array([1, 1, 1, 1, 2]), 0, 4, 1]
# supp: [2 1 4]
# Ahat: [[ 2.          0.34899272 -0.53074882]
#  [ 0.34899272  2.          0.58575358]
#  [-0.53074882  0.58575358  2.        ]]
# bhat: [-0.63526821 -1.23857424 -0.75933276]
# c: 2.9453397619274906
# xout,fout: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xtilde, fxtilde: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xlb,fxlb: [[-0.07733803]
#  [ 0.47376649]
#  [ 0.29889061]
#  [ 0.17745594]
#  [ 0.33847943]] 2.403649040818212
# V2 added: [array([1, 1, 1, 1, 2]), 0, 4, 1]
# Selected node Y: (2.403649040818212, 1, array([1, 1, 1, 1, 2]), 0, 4, 1, array([[-0.07733803],
#        [ 0.47376649],
#        [ 0.29889061],
#        [ 0.17745594],
#        [ 0.33847943]]))
# par_dir: [3 2 1 0]
# V0: [array([1, 1, 1, 0, 2]), 1, 3, 1]
# supp: [2 1 4]
# Ahat: [[ 2.          0.34899272 -0.53074882]
#  [ 0.34899272  2.          0.58575358]
#  [-0.53074882  0.58575358  2.        ]]
# bhat: [-0.63526821 -1.23857424 -0.75933276]
# n1,n2,p,r: 3 1 5 5
# id: [ 0  1  2 -4]
# A0: [[ 2.         -0.36060233  0.4090279   0.83474769  0.87273784  0.24027198]
#  [-0.36060233  2.          0.34899272 -0.22215772  0.58575358  1.23857424]
#  [ 0.4090279   0.34899272  2.          0.47012747 -0.53074882  0.63526821]
#  [ 0.83474769 -0.22215772  0.47012747  2.          0.17466388  0.38474006]
#  [ 0.87273784  0.58575358 -0.53074882  0.17466388  2.          0.75933276]]
# E0: [[ 1.         -0.18030116  0.20451395  0.41737385  0.43636892  0.12013599]
#  [ 0.          1.          0.21847268 -0.03702965  0.38403915  0.66248415]
#  [ 0.          0.          1.          0.17273326 -0.47784505  0.16780243]
#  [ 0.          0.          0.          1.         -0.00722805  0.1750094 ]
#  [ 0.          0.          0.          0.          1.          0.33847943]]
# d: 4
# cia: [0 1 2 4]
# E0[:,cia]: [[ 1.         -0.18030116  0.20451395  0.43636892]
#  [ 0.          1.          0.21847268  0.38403915]
#  [ 0.          0.          1.         -0.47784505]
#  [ 0.          0.          0.         -0.00722805]
#  [ 0.          0.          0.          1.        ]]
# E0[:,p]: [0.12013599 0.66248415 0.16780243 0.1750094  0.33847943]
# tempE[cia[:n1],:]: [[ 1.         -0.18030116  0.20451395  0.43636892  0.12013599]
#  [ 0.          1.          0.21847268  0.38403915  0.66248415]
#  [ 0.          0.          1.         -0.47784505  0.16780243]]
# cia[n1:d], np.concatenate((cia,[p])): [4] [0 1 2 4 5]
# A0[cia[n1:d], np.concatenate((cia,[p])) ]: [[ 0.87273784  0.58575358 -0.53074882  2.          0.75933276]]
# E0: [[ 1.         -0.18030116  0.20451395  0.43636892  0.12013599]
#  [ 0.          1.          0.21847268  0.38403915  0.66248415]
#  [ 0.          0.          1.         -0.47784505  0.16780243]
#  [ 0.          0.          0.          0.91729874  0.30844153]]
# Updated EF xhat: [[0.00675474]
#  [0.47517019]
#  [0.31518968]
#  [0.        ]
#  [0.30844153]]
# xlbV0,fxlbV0: [[0.00675474]
#  [0.47517019]
#  [0.31518968]
#  [0.        ]
#  [0.30844153]] 2.429107684445268
# V0 got deleted using DC1
# V2: [array([1, 1, 1, 2, 2]), 0, 3, 2]
# supp: [2 1 4]
# Ahat: [[ 2.          0.34899272 -0.53074882]
#  [ 0.34899272  2.          0.58575358]
#  [-0.53074882  0.58575358  2.        ]]
# bhat: [-0.63526821 -1.23857424 -0.75933276]
# c: 2.9453397619274906
# xout,fout: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xtilde, fxtilde: [[0.        ]
#  [0.46651321]
#  [0.32350718]
#  [0.        ]
#  [0.32888602]] 2.4288102621281933
# xlb,fxlb: [[-0.07733803]
#  [ 0.47376649]
#  [ 0.29889061]
#  [ 0.17745594]
#  [ 0.33847943]] 2.403649040818212
# V2 added: [array([1, 1, 1, 2, 2]), 0, 3, 2]
# ET: [[ 1.         -0.35485915  0.73900147 -0.41936066  0.8629648  -0.39781133
#   -1.23775551  1.26812186 -2.21902784  0.75872635]
#  [ 0.          1.         -3.06739299  2.07954916 -5.26684888  4.37513021
#    0.96738502 -6.24255548 12.69620805 -6.54147509]
#  [ 0.          0.          0.          1.         -2.00029337 -1.20511879
#    2.36192321 -0.22108135  0.1774518  -0.1128815 ]
#  [ 0.          0.          0.          0.          1.          2.90818423
#   -6.35576004  0.78150706  3.02428501 -1.35821625]]
# n1,n2,p,r: 2 2 5 5
# id: [ 0  1 -3 -4]
# A0: [[ 2.         -0.36060233  0.4090279   0.83474769  0.87273784  0.24027198]
#  [-0.36060233  2.          0.34899272 -0.22215772  0.58575358  1.23857424]
#  [ 0.4090279   0.34899272  2.          0.47012747 -0.53074882  0.63526821]
#  [ 0.83474769 -0.22215772  0.47012747  2.          0.17466388  0.38474006]
#  [ 0.87273784  0.58575358 -0.53074882  0.17466388  2.          0.75933276]]
# E0: [[ 1.         -0.18030116  0.20451395  0.41737385  0.43636892  0.12013599]
#  [ 0.          1.          0.21847268 -0.03702965  0.38403915  0.66248415]
#  [ 0.          0.          1.          0.17273326 -0.47784505  0.16780243]
#  [ 0.          0.          0.          1.         -0.00722805  0.1750094 ]
#  [ 0.          0.          0.          0.          1.          0.33847943]]
# d: 4
# cia: [0 1 3 4]
# E0[:,cia]: [[ 1.         -0.18030116  0.41737385  0.43636892]
#  [ 0.          1.         -0.03702965  0.38403915]
#  [ 0.          0.          0.17273326 -0.47784505]
#  [ 0.          0.          1.         -0.00722805]
#  [ 0.          0.          0.          1.        ]]
# E0[:,p]: [0.12013599 0.66248415 0.16780243 0.1750094  0.33847943]
# tempE[cia[:n1],:]: [[ 1.         -0.18030116  0.41737385  0.43636892  0.12013599]
#  [ 0.          1.         -0.03702965  0.38403915  0.66248415]]
# cia[n1:d], np.concatenate((cia,[p])): [3 4] [0 1 3 4 5]
# A0[cia[n1:d], np.concatenate((cia,[p])) ]: [[ 0.83474769 -0.22215772  2.          0.17466388  0.38474006]
#  [ 0.87273784  0.58575358  0.17466388  2.          0.75933276]]
# E0: [[ 1.         -0.18030116  0.41737385  0.43636892  0.12013599]
#  [ 0.          1.         -0.03702965  0.38403915  0.66248415]
#  [ 0.          0.          1.64894491 -0.162077    0.33192497]
#  [ 0.          0.         -0.162077    1.33378129  0.16218746]]
# Updated EF xhat: [[0.01046214]
#  [0.61346227]
#  [0.        ]
#  [0.35821183]
#  [0.16218746]]
# xlbV0,fxlbV0: [[0.01046214]
#  [0.61346227]
#  [0.        ]
#  [0.35821183]
#  [0.16218746]] 2.4750040560358872
# V0 got deleted using DC1
# V2: [array([1, 1, 2, 2, 2]), 0, 2, 3]
# DC2 is true for all V2 boxes
# supp: [2 3 4]
# supp,Ahat,bhat,c,start_pt: [2 3 4] [[ 2.          0.47012747 -0.53074882]
#  [ 0.47012747  2.          0.17466388]
#  [-0.53074882  0.17466388  2.        ]] [-0.63526821 -0.38474006 -0.75933276] 2.9453397619274906 [-0.63526821 -0.38474006 -0.75933276]
# alg. converged
# start, end: 1.65625 1.8125
# xibbef: [[0.32350718]
#  [0.        ]
#  [0.        ]
#  [0.46651321]
#  [0.32888602]]
# fibbef: 2.4288102621281933
# cpu ibbef: 0.15625
# Set parameter Username
# Set parameter LicenseID to value 2632165
# Academic license - for non-commercial use only - expires 2026-03-06
# obj: -0.6352682055742652 <gurobi.Var *Awaiting Model Update*> + -0.38474006300866903 <gurobi.Var *Awaiting Model Update*> + -0.24027197652166346 <gurobi.Var *Awaiting Model Update*> + -1.2385742369457515 <gurobi.Var *Awaiting Model Update*> + -0.7593327634996179 <gurobi.Var *Awaiting Model Update*> + [ 0.9999999999999998 <gurobi.Var *Awaiting Model Update*> ^ 2 + 0.23506373700296498 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.2045139521772815 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.17449635977315328 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + -0.2653744103212772 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.23506373700296498 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.9999999999999999 <gurobi.Var *Awaiting Model Update*> ^ 2 + 0.41737384517149867 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + -0.11107886247984886 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.0873319375941125 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.2045139521772815 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.41737384517149867 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + <gurobi.Var *Awaiting Model Update*> ^ 2 + -0.18030116327505868 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.43636892042244646 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.17449635977315328 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + -0.11107886247984886 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + -0.18030116327505868 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + <gurobi.Var *Awaiting Model Update*> ^ 2 + 0.29287678828465225 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + -0.2653744103212772 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.0873319375941125 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.43636892042244646 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.29287678828465225 <gurobi.Var *Awaiting Model Update*> * <gurobi.Var *Awaiting Model Update*> + 0.9999999999999998 <gurobi.Var *Awaiting Model Update*> ^ 2 ]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-7700 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 11 rows, 10 columns and 25 nonzeros
# Model fingerprint: 0x406c9a3f
# Model has 15 quadratic objective terms
# Variable types: 5 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [2e-01, 1e+00]
#   QObjective range [3e-01, 2e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [3e+00, 3e+00]
# Presolve time: 0.00s
# Presolved: 26 rows, 15 columns, 55 nonzeros
# Presolved model has 20 quadratic objective terms
# Variable types: 10 continuous, 5 integer (5 binary)
# Found heuristic solution: objective -0.1156596
# Found heuristic solution: objective -0.4489114
#
# Root relaxation: objective -5.416907e-01, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.54169    0    5   -0.44891   -0.54169  20.7%     -    0s
# H    0     0                      -0.5165295   -0.54169  4.87%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: -0.516529 -0.448911 -0.11566
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.165294997993e-01, best bound -5.165294997993e-01, gap 0.0000%
# xmio: [0.3235071780189642, 0.0, 0.0, 0.46651321322276385, 0.3288860167479406]
# bx: [[-1.033059]]
# xAx: [[1.033059]]
# fxout: [[2.42881026]]
# xmio: [[0.32350718]
#  [0.        ]
#  [0.        ]
#  [0.46651321]
#  [0.32888602]]
# fmio: 2.4288102621281933
# cpu mio: 0.0
# rss: [[2.42881026 2.42881026]]
# cpu: [[0.15625 0.     ]]
